# %%
import platform
print platform.linux_distribution()
# Out:
# ('Fedora', '20', 'Heisenbug')

# %%
# Get the SVG from systemd-analyze plot
# and display it
import subprocess
svg = subprocess.check_output(['systemd-analyze','plot'])

from IPython.display import SVG
SVG(svg)
